# %% [markdown]
# <a href="https://colab.research.google.com/github/ngophuocthanh2005-ctrl/phuocthanh.github.io/blob/main/02_KTLTSP_TH_Bai_tap_thuc_hanh_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BÀI TẬP THỰC HÀNH

# %%
# Bài 1. In chuỗi
# Viết chương trình in ra 2 dòng chữ sau ra màn hình Console:
print("Whoever is happy will make others happy too")
print("--Anne Frank");
# Out:
# Whoever is happy will make others happy too
# --Anne Frank

# %%
# Bài 2. Biểu thức tính toán
# Viết chương trình nhập vào hai số nguyên a và b. Hãy tính toán kết quả của các biểu thức sau A+B, A-B, A*B, A/B (chia lấy nguyên), A%B (chia lấy dư), A / B (chia lẻ) (làm tròn 2 số lẻ).
# Khi in ra, kết quả có dạng “A [+,-,*,/,%] B = C”. A được căn lề trái 5, + (bình thường), B căn lề phải 5, dấu = bình thường, C căn lề phải 5.

# Nhập dữ liệu
a = int(input("Moi ban nhap so a: "))
b = int(input("Moi ban nhap so b: "))

# Xử lý
kqCong = a + b
kqTru = a - b
kqNhan = a * b
kqChiaNguyen = a // b
kqDu= a % b
kqChiaThuc = a / b

# Xuất dữ liệu
print("Cac ket qua tinh toan: ")
print("%-5d + %5d = %5d"%(a, b, kqCong))
print("%-5d - %5d = %5d"%(a, b, kqTru))
print("%-5d * %5d = %5d"%(a, b, kqNhan))
print("%-5d / %5d = %5d"%(a, b, kqChiaNguyen))
print("%-5d / %5d = %5d"%(a, b, kqDu))
print("%-5d / %5d = %5.2f"%(a, b, kqChiaThuc))
# Out:
# Moi ban nhap so a: 4
# Moi ban nhap so b: 7
# Cac ket qua tinh toan:
# 4     +     7 =    11
# 4     -     7 =    -3
# 4     *     7 =    28
# 4     /     7 =     0
# 4     /     7 =     4
# 4     /     7 =  0.57

# %%
# Bài 3. Biểu thức so sánh
# Viết chương trình nhập vào hai số thực a và b. Hãy viết chương trình ước lượng các biểu thức so sánh A>B, A<B, A>=B, A<=B, A==B, A!=B. Số thực được định dạng có hai số lẻ, có dấu phân cách hàng ngàn.

# Nhập dữ liệu
a = float(input("Moi ban nhap so a: "))
b = float(input("Moi ban nhap so b: "))

# Xử lý
laNhoHon = (a < b)
laNhoHonBang = (a <= b)
laLonHon = (a > b)
laLonHonBang = (a >= b)
laBang = (a == b)
laKhacNhau = (a != b)

# Xuất dữ liệu
print("Ket qua so sanh hai so thuc %.2f va %.2f:"%(a, b))
print("%-8.2f < %8.2f: %8s"%(a, b, laNhoHon))
print("%-8.2f <= %8.2f: %8s"%(a, b, laNhoHonBang))
print("%-8.2f > %8.2f: %8s"%(a, b, laLonHon))
print("%-8.2f >= %8.2f: %8s"%(a, b, laLonHonBang))
print("%-8.2f == %8.2f: %8s"%(a, b, laBang))
print("%-8.2f != %8.2f: %8s"%(a, b, laKhacNhau))
# Out:
# Moi ban nhap so a: 4
# Moi ban nhap so b: 7.9
# Ket qua so sanh hai so thuc 4.00 va 7.90:
# 4.00     <     7.90:     True
# 4.00     <=     7.90:     True
# 4.00     >     7.90:    False
# 4.00     >=     7.90:    False
# 4.00     ==     7.90:    False
# 4.00     !=     7.90:     True

# %% [markdown]
# ![Screenshot 2025-08-24 173849.png](data:image/png;base64,...)

# %%
import math
# Nhập dữ liệu
x = float(input("Moi ban nhap vao gia tri cua bien so x: "))

# Xử lý
fx = x + math.pow(x, 5) / (1 * 2 * 3 * 4 * 5) + math.sqrt(abs(x)) / math.pow(x, 3.0 / 2)

# Xuất dữ liệu
print("Gia tri cua ham so f(%.2f) = %.2f."%(x, fx))
# Out:
# Moi ban nhap vao gia tri cua bien so x: 2.3
# Gia tri cua ham so f(2.30) = 3.27.

# %%
# Bài 5. Tổng chữ số
# Cho số nguyên n có 4 chữ số. Hãy tính tổng các chữ số của n.
# Ví dụ: n = 1234 → kq = 10

import math
# Nhập dữ liệu
n = int(input("Mời bạn nhập số nguyên có 4 chữ số: "))

# Tách từng chữ số
a = n // 1000
b = (n // 100) % 10
c = (n // 10) % 10
d = n % 10

# Tính tổng
tong = a + b + c + d

# Xuất kết quả
print(f"Tổng các chữ số của {n} là: {tong}")
# Out:
# Mời bạn nhập số nguyên có 4 chữ số: 4567
# Tổng các chữ số của 4567 là: 22

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# BÀI 1
print("**************************")
print("* Truong: Dai Hoc UEH    *")
print("* Khoa: CNTT             *")
print("* Ho ten:                *")
print("**************************")
# Out:
# **************************
# * Truong: Dai Hoc UEH    *
# * Khoa: CNTT             *
# * Ho ten:                *
# **************************

# %%
# BÀI 2
R = float(input("Nhap ban kinh R: "))
S = 3.14 * R * R
P = 2 * 3.14 * R
print("Dien tich S =", round(S,1))
print("Chu vi P =", round(P,1))
# Out:
# Nhap ban kinh R: 7
# Dien tich S = 153.9
# Chu vi P = 44.0

# %%
# Bài 3. Đổi sang giây DoiSangGiay.*
# Một thiết bị hoạt động được h giờ, m phút và s giây. Hãy viết chương trình chuyển thời gian đó sang tổng số giây.
h = int(input("Nhap so gio: "))
m = int(input("Nhap so phut: "))
s = int(input("Nhap so giay: "))

if h < 0 or m < 0 or m >= 60 or s < 0 or s >= 60:
    print("Thoi gian khong hop le!")
else:
    tong = h*3600 + m*60 + s
    print("Tong so giay cua %d:%d:%d la %d giay" % (h, m, s, tong))
# Out:
# Nhap so gio: 2
# Nhap so phut: 3
# Nhap so giay: 4
# Tong so giay cua 2:3:4 la 7384 giay

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# BÀI 4
t = int(input("Nhap vao tong so giay: "))

if t < 0:
    print("So giay phai >= 0")
else:
    h = t // 3600
    t = t % 3600
    m = t // 60
    s = t % 60
    print("%d giay co dang %d:%d:%d" % (h*3600+m*60+s, h, m, s))
# Out:
# Nhap vao tong so giay: 567384
# 567384 giay co dang 157:36:24

# %%
# BÀI 5
import math

a = float(input("Nhap do dai canh a: "))
b = float(input("Nhap do dai canh b: "))
c = float(input("Nhap do dai canh c: "))

if a <= 0 or b <= 0 or c <= 0:
    print("Canh tam giac phai lon hon 0!")
elif (a + b <= c) or (a + c <= b) or (b + c <= a):
    print("Ba canh khong tao thanh tam giac hop le!")
else:
    p = (a + b + c) / 2
    S = math.sqrt(p*(p-a)*(p-b)*(p-c))
    print("Dien tich tam giac S = %.2f" % S)
# Out:
# Nhap do dai canh a: 4
# Nhap do dai canh b: 5
# Nhap do dai canh c: 6
# Dien tich tam giac S = 9.92

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# BÀI 6
a = float(input("Nhap so thuc a: "))
n = int(input("Nhap so mu n: "))

ketqua = a ** n
print("Ket qua %g^%d = %g" % (a, n, ketqua))
# Out:
# Nhap so thuc a: 3
# Nhap so mu n: 2
# Ket qua 3^2 = 9

# %%
#BÀI 7
x = int(input("Nhap so nguyen x (4 chu so): "))

if x < 1000 or x > 9999:
    print("x phai la so nguyen co 4 chu so!")
else:
    y = int(str(x)[::-1])   # đảo chuỗi rồi đổi lại thành số
    print("So dao cua %d la %d" % (x, y))
# Out:
# Nhap so nguyen x (4 chu so): 4562
# So dao cua 4562 la 2654

# %%
# BÀI 8
import math

deg = float(input("Nhap goc (do): "))
rad = deg * math.pi / 180
print("Goc %.2f do = %.4f radian" % (deg, rad))
# Out:
# Nhap goc (do): 56
# Goc 56.00 do = 0.9774 radian

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# BÀI 9
import math

x = float(input("Nhap so thuc x: "))

if x < 0:
    print("x phai >= 0 (vi co can bac 2 cua x).")
else:
    y1 = 4 * (x**2 + 10*x*math.sqrt(x) + 3*x + 1)
    y2 = (math.sin(math.pi * x**2) + math.sqrt(x**2 + 1)) / (math.e**(2*x) + math.cos((math.pi/4)*x))
    print("y1 = %.2f" % y1)
    print("y2 = %.2f" % y2)
# Out:
# Nhap so thuc x: 52
# y1 = 26443.09
# y2 = 0.00

# %%
# BÀI 10
import math

x1 = float(input("Nhap x1: "))
y1 = float(input("Nhap y1: "))
x2 = float(input("Nhap x2: "))
y2 = float(input("Nhap y2: "))

d = math.hypot(x2 - x1, y2 - y1)   # tương đương sqrt((dx)^2 + (dy)^2)
print("Khoang cach AB = %.2f" % d)
# Out:
# Nhap x1: 5
# Nhap y1: 2
# Nhap x2: 4
# Nhap y2: 2
# Khoang cach AB = 1.00

# %% [markdown]
# CẤU TRÚC ĐIỀU KIỆN
